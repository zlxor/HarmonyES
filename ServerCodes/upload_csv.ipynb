# %%
def load_csv(csv_file_path, csv_file_name, table_name, database='test'):
    # open csv file
    file = open(csv_file_path, 'r',encoding='utf-8')
   
    # read in the inndex name of the csv file and create table
    reader = file.readline()
    b = reader.split(',')
    colum = ''
    for a in b:
        colum = colum + a + ' varchar(255),'
    colum = colum[:-1]
    
    # import data with data_sql
    data_sql = "LOAD DATA LOCAL INFILE '%s' INTO TABLE %s FIELDS TERMINATED BY ',' \
LINES TERMINATED BY '\\r\\n' IGNORE 1 LINES" % (csv_file_name,table_name)
 
    # use the database
    cur.execute('use %s' % database)
    
    cur.execute('SET NAMES utf8;')
    cur.execute('SET character_set_connection=utf8;')
    
    # execute data_sql and import data
    cur.execute(data_sql)
    conn.commit()
    
    # close connection
    conn.close()
    cur.close()

# %%
def upload():
    import pymysql

    config = {'host':'192.168.0.212',
                  'port':3306,
                  'user':'root',
                  'passwd':'Aa111111#',
                  'charset':'utf8mb4',
                  'local_infile':1
                  }
    conn = pymysql.connect(**config)
    cur = conn.cursor()

    load_csv('/root/HarmonyES/weather_predict.csv', 'weather_predict.csv', 'weather_predict', 'harmonyes' )

    config = {'host':'192.168.0.212',
                  'port':3306,
                  'user':'root',
                  'passwd':'Aa111111#',
                  'charset':'utf8mb4',
                  'local_infile':1
                  }
    conn = pymysql.connect(**config)
    cur = conn.cursor()
    load_csv('/root/HarmonyES/weather_history.csv', 'weather_history.csv', 'weather_history', 'harmonyes' )

    config = {'host':'192.168.0.212',
                  'port':3306,
                  'user':'root',
                  'passwd':'Aa111111#',
                  'charset':'utf8mb4',
                  'local_infile':1
                  }
    conn = pymysql.connect(**config)
    cur = conn.cursor()

    load_csv('/root/HarmonyES/schedule.csv', 'schedule.csv', 'schedule', 'harmonyes' )

    config = {'host':'192.168.0.212',
                  'port':3306,
                  'user':'root',
                  'passwd':'Aa111111#',
                  'charset':'utf8mb4',
                  'local_infile':1
                  }
    conn = pymysql.connect(**config)
    cur = conn.cursor()

    load_csv('/root/HarmonyES/schedule_history.csv', 'schedule_history.csv', 'schedule_history', 'harmonyes' )


    config = {'host':'192.168.0.212',
                  'port':3306,
                  'user':'root',
                  'passwd':'Aa111111#',
                  'charset':'utf8mb4',
                  'local_infile':1
                  }
    conn = pymysql.connect(**config)
    cur = conn.cursor()

    load_csv('/root/HarmonyES/controlled_nodes.csv', 'controlled_nodes.csv', 'controlled_nodes', 'harmonyes' )


    config = {'host':'192.168.0.212',
                  'port':3306,
                  'user':'root',
                  'passwd':'Aa111111#',
                  'charset':'utf8mb4',
                  'local_infile':1
                  }
    conn = pymysql.connect(**config)
    cur = conn.cursor()

    load_csv('/root/HarmonyES/weather_based_nodes.csv', 'weather_based_nodes.csv', 'weather_based_nodes', 'harmonyes' )
